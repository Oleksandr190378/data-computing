# %% [markdown]
# <a href="https://colab.research.google.com/github/Oleksandr190378/expert-computing-machine/blob/main/Hm2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8"
data = pd.read_html(
    url,
    match="Коефіцієнт народжуваності в регіонах України",
    decimal=",",
    thousands=".",
)[0]

# %%
data.head()
# Out:
#              Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0              Крим  23.0  20.6  16.0  13.0   7.3  12.6     —     —
# 1         Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2         Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3  Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4          Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2     —

# %%
data.shape
# Out:
# (28, 9)

# %%
data[['2014', '2019']] = data[['2014', '2019']].apply(pd.to_numeric, errors='coerce')

# %%
data.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 2000      float64
# 2012      float64
# 2014      float64
# 2019      float64
# dtype: object

# %%
data
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# 12          Львівська  23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# 13       Миколаївська  21.1  19.4  15.5  13.7   8.0  11.5  11.2   7.1
# 14            Одеська  24.1  19.2  14.8  12.6   8.0  12.7  12.3   8.8
# 15         Полтавська  18.6  16.3  13.1  11.8   7.0   9.9  10.0   6.5
# 16         Рівненська  26.9  26.7  19.3  15.8  11.8  15.9  14.8  10.7
# 17            Сумська  21.6  18.4  13.2  11.5   7.0   9.7   9.2   6.0
# 18      Тернопільська  21.3  21.6  15.7  14.2   9.2  11.3  10.9   7.6
# 19         Харківська  19.7  17.3  14.0  11.4   6.8   9.9  10.1   6.8
# 20         Херсонська  20.8  21.4  16.6  14.3   8.5  11.7  11.5   8.1
# 21        Хмельницька  23.4  19.8  14.8  12.9   8.5  11.3  11.2   7.9
# 22          Черкаська  20.5  17.9  14.4  12.3   7.5  10.0   9.8   6.4
# 23        Чернівецька  24.7  21.8  17.0  14.8  10.1  12.8  12.9   9.2
# 24       Чернігівська  22.0  18.3  12.7  10.8   6.9   9.4   9.0   6.1
# 25               Київ  23.1  17.4  15.9  12.0   7.3  12.0  12.1  11.0
# 26        Севастополь  23.1  20.7  15.6  12.5   7.0  12.0   NaN   NaN
# 27            Україна  22.8  20.5  15.2  12.6   7.8  11.4  11.1   8.1

# %%
data.isnull().sum()
# Out:
# Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      2
# 2019      4
# dtype: int64

# %%
data.drop([len(data)-1], inplace=True)

# %%
data.iloc[:, 1:].apply(lambda col: col.fillna(col.mean()).round(1), axis=0)
# Out:
#     1950  1960  1970  1990  2000  2012  2014  2019
# 0   23.0  20.6  16.0  13.0   7.3  12.6  11.1   8.0
# 1   22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2   24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3   20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4   27.1  21.4  14.0  10.9   6.1   9.8   8.2   8.0
# 5   26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6   31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7   21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9   20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11  26.2  23.5  14.4  11.6   6.2   9.6   5.1   8.0
# 12  23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# 13  21.1  19.4  15.5  13.7   8.0  11.5  11.2   7.1
# 14  24.1  19.2  14.8  12.6   8.0  12.7  12.3   8.8
# 15  18.6  16.3  13.1  11.8   7.0   9.9  10.0   6.5
# 16  26.9  26.7  19.3  15.8  11.8  15.9  14.8  10.7
# 17  21.6  18.4  13.2  11.5   7.0   9.7   9.2   6.0
# 18  21.3  21.6  15.7  14.2   9.2  11.3  10.9   7.6
# 19  19.7  17.3  14.0  11.4   6.8   9.9  10.1   6.8
# 20  20.8  21.4  16.6  14.3   8.5  11.7  11.5   8.1
# 21  23.4  19.8  14.8  12.9   8.5  11.3  11.2   7.9
# 22  20.5  17.9  14.4  12.3   7.5  10.0   9.8   6.4
# 23  24.7  21.8  17.0  14.8  10.1  12.8  12.9   9.2
# 24  22.0  18.3  12.7  10.8   6.9   9.4   9.0   6.1
# 25  23.1  17.4  15.9  12.0   7.3  12.0  12.1  11.0
# 26  23.1  20.8  15.6  12.5   7.0  12.0  11.1   8.0

# %%
regions =  data[data['2019'] > data['2019'].mean()]['Регіон'].tolist()
regions
# Out:
# ['Волинська',
#  'Закарпатська',
#  'Івано-Франківська',
#  'Львівська',
#  'Одеська',
#  'Рівненська',
#  'Херсонська',
#  'Чернівецька',
#  'Київ']

# %%
region = data[data['2014'] == data['2014'].max()]['Регіон'].tolist()
region
# Out:
# ['Рівненська']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,8))
plt.bar(data['Регіон'], data['2019'], color='b')
plt.xlabel("Регіон", fontsize="small", color="midnightblue")
plt.xticks(rotation=45)
plt.ylabel("Кількість", fontsize="small", color="midnightblue")
plt.title("Рівень народжуваності по регіонах у 2019 році", fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt

hm_data = data[data['Регіон'] == 'Хмельницька']
print(hm_data)
plt.plot(hm_data.columns[1:], hm_data.values[0, 1:], color='b', label="Рівень народжуваності")
plt.xlabel("Pik", fontsize="small", color="midnightblue")
plt.xticks(rotation=45)
plt.ylabel("Рівень народжуваності ", fontsize="small", color="midnightblue")
plt.title("Рівень народжуваності в Хмельницькій області", fontsize=15)
plt.legend()
plt.grid()
plt.show()
# Out:
#          Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 21  Хмельницька  23.4  19.8  14.8  12.9   8.5  11.3  11.2   7.9

# %%
import matplotlib.pyplot as plt

hm_data = data[data['Регіон'] == 'Київ']
plt.plot(hm_data.columns[1:], hm_data.values[0, 1:], linestyle="--",
    color="#FF5733",label="Рівень народжуваності")
plt.xlabel("Pik", fontsize="small", color="midnightblue")
plt.xticks(rotation=45)
plt.ylabel("Рівень народжуваності ", fontsize="small", color="midnightblue")
plt.title("Рівень народжуваності в Києві", fontsize=15)
plt.legend()
plt.grid()
plt.show()
