# %% [markdown]
# <a href="https://colab.research.google.com/github/Oleksandr190378/expert-computing-machine/blob/main/Hm2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path = r'/content/drive/My Drive/Colab Notebooks/2017_jun_final.csv'
users = pd.read_csv(file_path)

users.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %%
users.shape
# Out:
# (8704, 25)

# %%
users.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
users.isnull().sum()
# Out:
# N                                      0
# Посада                                 0
# Мова програмування                  3850
# Спеціалізація                       7219
# Загальний досвід роботи                0
# Досвід роботи на поточному місці       0
# Зарплата на місяць                     0
# Зміна зарплати за 12 місяців           0
# Місто                                  0
# Розмір компанії                        0
# Тип компанії                           0
# Стать                                  0
# Вік                                    0
# Освіта                                 0
# Університет                          358
# Ще студент                             0
# Рівень англійської                     0
# Предметна область                    223
# Дата заповнення                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# ...

# %%
users = users[[col for col in users.columns if (users[col].notna().all() or col == "Мова програмування")]]
users.columns
# Out:
# Index(['N', 'Посада', 'Мова програмування', 'Загальний досвід роботи',
#        'Досвід роботи на поточному місці', 'Зарплата на місяць',
#        'Зміна зарплати за 12 місяців', 'Місто', 'Розмір компанії',
#        'Тип компанії', 'Стать', 'Вік', 'Освіта', 'Ще студент',
#        'Рівень англійської', 'Дата заповнення', 'User.Agent', 'exp',
#        'current_job_exp', 'salary'],
#       dtype='object')

# %%
users.isnull().sum()
# Out:
# N                                      0
# Посада                                 0
# Мова програмування                  3850
# Загальний досвід роботи                0
# Досвід роботи на поточному місці       0
# Зарплата на місяць                     0
# Зміна зарплати за 12 місяців           0
# Місто                                  0
# Розмір компанії                        0
# Тип компанії                           0
# Стать                                  0
# Вік                                    0
# Освіта                                 0
# Ще студент                             0
# Рівень англійської                     0
# Дата заповнення                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# dtype: int64

# %%
users = users.dropna()

# %%
users.shape
# Out:
# (4854, 20)

# %%
python_data = users.loc[users['Мова програмування'] == 'Python']
python_data.head()
# Out:
#        N                    Посада Мова програмування Загальний досвід роботи  \
# 12    13         Software Engineer             Python                       1
# 68    69         Software Engineer             Python                     1.5
# 87    88  Junior Software Engineer             Python                     0.5
# 114  115  Junior Software Engineer             Python                     1.5
# 143  144  Junior Software Engineer             Python                       1
#
#     Досвід роботи на поточному місці  Зарплата на місяць  \
# 12                   менше 3 місяців                 800
# 68                               0.5                 900
# 87                               0.5                 600
# 114                              0.5                 685
# 143                                1                 750
#
#      Зміна зарплати за 12 місяців Місто Розмір компанії   Тип компанії  \
# 12                            200  Київ      до 50 осіб  Аутсорсингова
# ...

# %%
python_data2 = users[users['Мова програмування'] == 'Python']
python_data2.head()
# Out:
#        N                    Посада Мова програмування Загальний досвід роботи  \
# 12    13         Software Engineer             Python                       1
# 68    69         Software Engineer             Python                     1.5
# 87    88  Junior Software Engineer             Python                     0.5
# 114  115  Junior Software Engineer             Python                     1.5
# 143  144  Junior Software Engineer             Python                       1
#
#     Досвід роботи на поточному місці  Зарплата на місяць  \
# 12                   менше 3 місяців                 800
# 68                               0.5                 900
# 87                               0.5                 600
# 114                              0.5                 685
# 143                                1                 750
#
#      Зміна зарплати за 12 місяців Місто Розмір компанії   Тип компанії  \
# 12                            200  Київ      до 50 осіб  Аутсорсингова
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df_corr = python_data[ ['Зарплата на місяць', 'Вік', 'exp', 'current_job_exp']].corr()
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
python_data.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Ще студент                             bool
# Рівень англійської                   object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# dtype: object

# %%
python_data.columns
# Out:
# Index(['N', 'Посада', 'Мова програмування', 'Загальний досвід роботи',
#        'Досвід роботи на поточному місці', 'Зарплата на місяць',
#        'Зміна зарплати за 12 місяців', 'Місто', 'Розмір компанії',
#        'Тип компанії', 'Стать', 'Вік', 'Освіта', 'Ще студент',
#        'Рівень англійської', 'Дата заповнення', 'User.Agent', 'exp',
#        'current_job_exp', 'salary'],
#       dtype='object')

# %%
 python_data.groupby(by="Посада")

# %%
DataFrame = python_data.groupby(by="Посада")["Зарплата на місяць"].agg( ['min', 'max'])
DataFrame
# Out:
#                            min   max
# Посада
# Junior Software Engineer   100  1250
# Senior Software Engineer  1300  9200
# Software Engineer          500  5400
# System Architect          3000  5000
# Technical Lead            1425  6200

# %%
DataFrame['avg']  = python_data.groupby('Посада')["Зарплата на місяць"].apply(lambda x: x.mean().round(2))

DataFrame
# Out:
#                            min   max      avg
# Посада
# Junior Software Engineer   100  1250   560.84
# Senior Software Engineer  1300  9200  3387.10
# Software Engineer          500  5400  1799.07
# System Architect          3000  5000  4000.00
# Technical Lead            1425  6200  3165.91

# %%
DataFrame['avg'].describe()
# Out:
# count       5.000000
# mean     2582.584000
# std      1387.256855
# min       560.840000
# 25%      1799.070000
# 50%      3165.910000
# 75%      3387.100000
# max      4000.000000
# Name: avg, dtype: float64

# %%
DataFrame.to_csv("my_data.csv", index=True)

# %%
a =pd.read_csv('my_data.csv')
a
# Out:
#                      Посада   min   max      avg
# 0  Junior Software Engineer   100  1250   560.84
# 1  Senior Software Engineer  1300  9200  3387.10
# 2         Software Engineer   500  5400  1799.07
# 3          System Architect  3000  5000  4000.00
# 4            Technical Lead  1425  6200  3165.91

# %%
import matplotlib.pyplot as plt
a = python_data['Посада'].drop_duplicates().to_list()
plt.bar(a, DataFrame['avg'], color='b')
plt.xlabel("Посада", fontsize="small", color="midnightblue")
plt.xticks(rotation=45)
plt.ylabel("Середня зарплата", fontsize="small", color="midnightblue")
plt.title("Рівень середньої зарплати відносно посади", fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,8))
plt.plot(python_data['Посада'], python_data['Зарплата на місяць'], 'm.')
plt.xlabel("Посада", fontsize="small", color="midnightblue")
plt.xticks(rotation=45)
plt.ylabel("Зарплата на місяць", fontsize="small", color="midnightblue")
plt.title("Рівень зарплати відносно посади", fontsize=15)
plt.grid()
plt.show()

# %%
import seaborn as sns
sns.set_style("darkgrid")

ax = python_data['salary'].plot(kind = 'hist', bins = 30, title = 'Кількість учасників з різним рівнем зарплати')
ax.set_xlabel('Розмір зарплати')
# Out:
# Text(0.5, 0, 'Розмір зарплати')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,8))
plt.plot(python_data['Рівень англійської'], python_data['Зарплата на місяць'], 'b.')
plt.xlabel("Рівень англійської", fontsize="small", color="midnightblue")
plt.xticks(rotation=45)
plt.ylabel("Зарплата на місяць", fontsize="small", color="midnightblue")
plt.title("Рівень зарплати відносно рівня англійської", fontsize=15)

plt.show()

# %%
labels =python_data['Посада'].drop_duplicates()
y = python_data["Посада"].value_counts().to_list()
explode = [0, 0, 0, 0, 0]
plt.pie( y, labels=labels,
    shadow=True,
    explode=explode,
    autopct="%.2f%%",
    pctdistance=1.15,
    labeldistance=1.35,)
plt.show()
